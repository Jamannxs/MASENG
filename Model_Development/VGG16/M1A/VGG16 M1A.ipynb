# %% [markdown]
# https://github.com/jhanwarakhil/vgg16_transfer_learning/blob/master/vgg_16_fruits.ipynb

# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import image_utils
import numpy as np

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline
from glob import glob

# %%
# import zipfile as zf #use for unzip files and keep in the same folder w/ manually combine into 1 folder

# # files1 = zf.ZipFile("snake.zip",'r')
# # files1.extractall()
# # files1.close()

# # files2 = zf.ZipFile("non-snake.zip",'r')
# # files2.extractall()
# # files2.close()

# files = zf.ZipFile("dataset.zip",'r')
# files.extractall()
# files.close()

# %%
# import splitfolders

# splitfolders.ratio("dataset", output="output", seed=1337, ratio=(.6, .2, .2), group_prefix=None, move=False)

# %%
IMAGE_SIZE = [224, 224] 

# training config:
epochs = 100 #One Epoch is when an Enter dataset is passed forward and backward through the neural network only once
batch_size = 32 #no. of the images that go in each round/ divide dataset into number of batches or set

# %%
train_path = './output_M1A/train'
valid_path = './output_M1A/val'
test_path = './output_M1A/test' #**************************

# %%
Training_path = './output_M1A/train/'
Validation_path = './output_M1A/val/'
Test_path = './output_M1A/test/'

# %%
import os

def number_of_imgs(path):
    print(path)
    for value in os.listdir(path):
        print(value, "has", len(os.listdir(path + value)), "imgs")
    print('\n')
    
    
number_of_imgs(Test_path)
number_of_imgs(Training_path)
number_of_imgs(Validation_path)
# Out:
# ./output_M1A/test/
# non-snake has 630 imgs
# snake has 630 imgs
#
#
# ./output_M1A/train/
# non-snake has 1890 imgs
# snake has 1890 imgs
#
#
# ./output_M1A/val/
# non-snake has 630 imgs
# snake has 630 imgs

# %%
image_files = glob(train_path + '/*/*.jp*g')
valid_image_files = glob(valid_path + '/*/*.jp*g')

# useful for getting number of classes
folders = glob(train_path + '/*')

print(len(image_files))
# Out:
# 3779

# %%
def create_dataframe(path):
    data = []
    for value in os.listdir(path):
        for image in os.listdir(path + value + "/"):
            file_path = path + value + "/" + image
            # if snake than set if to 1 else 0
            snake = 1 if value.lower() == "snake" else 0
            data.append({"path": file_path, 'snake': snake})
            
    df = pd.DataFrame(data=data).sample(frac=1).reset_index(drop=True)

    return df

# %%
# %matplotlib inline
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def plot_imgs(title, paths):
    fig = plt.figure(figsize=(14, 8), dpi=72)
    fig.suptitle(title, fontsize=24, y=1.05)
    for i, row in paths.iterrows():
        img=mpimg.imread(row['path'])
        plt.subplot(3, 5, i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        subtitle = 'YES' if row['snake'] == 1 else 'NO'
        plt.title(subtitle)
        plt.imshow(img)
    plt.tight_layout()
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None)
    plt.show()
    
    
plot_imgs("Test", create_dataframe(Test_path).sample(15).reset_index(drop=True))
plot_imgs("Train", create_dataframe(Training_path).sample(15).reset_index(drop=True))
plot_imgs("Validation", create_dataframe(Validation_path).sample(15).reset_index(drop=True))

# %% [markdown]
# # Start VGG model

# %%
vgg=VGG16(include_top=False,weights='imagenet',input_shape=(224,224,3))

# %%
for layer in vgg.layers:
    layer.trainable =False

# %%
x=Flatten()(vgg.output)
prediction=Dense(len(folders),activation='softmax')(x)
model=Model(inputs=vgg.input,outputs=prediction)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 2)                 50178
#
# =================================================================
# Total params: 14,764,866
# Trainable params: 50,178
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# # Optimizer: rmsprop, SDG, adam, adadelta, adagrad, adamax, nadam, ftrl

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
gen=ImageDataGenerator(rotation_range=20,width_shift_range=0.1,height_shift_range=0.1,shear_range=0.1,zoom_range=0.2,horizontal_flip=True,vertical_flip=True,preprocessing_function=preprocess_input)

# %%
test_gen=gen.flow_from_directory(test_path,target_size=IMAGE_SIZE)
# Out:
# Found 1260 images belonging to 2 classes.

# %%
labels = [None] * len(test_gen.class_indices)
print(labels)
for k, v in test_gen.class_indices.items():
  labels[v] = k
print(labels[0])
# Out:
# [None, None]
# non-snake

# %%
for x, y in test_gen:
  print("min:", x[0].min(), "max:", x[0].max())
  print(y[0])
  plt.title(labels[np.argmax(y[0])])
  plt.imshow(x[0])
  plt.show()
  break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# min: -123.68 max: 151.061
# [1. 0.]

# %%
train_generator = gen.flow_from_directory(
  train_path,
  target_size=IMAGE_SIZE,
  shuffle=True,
  batch_size=batch_size,
)
valid_generator = gen.flow_from_directory(
  valid_path,
  target_size=IMAGE_SIZE,
  shuffle=True,
  batch_size=batch_size,
)
# Out:
# Found 3780 images belonging to 2 classes.
# Found 1260 images belonging to 2 classes.

# %% [markdown]
# ### Model.fit version 1 for specific epochs

# %%
# #if you run version 2, do not run this cell

# # download
# import imageio
# imageio.plugins.freeimage.download()

# r = model.fit(
#   train_generator,
#   validation_data=valid_generator,
#   epochs=epochs
# )

# %% [markdown]
# ### Model.fit version 2 for avg epochs (early stopping)

# %%
#if you want to run version 1, do not run this cell

#create callback + early stopping 
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

filepath = './saved_RAW/M1A_VGG16/VGG16_M1A_model.hdf5'
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_loss', verbose=1, save_weights_only=True, mode='min')
early = EarlyStopping(monitor='val_loss', patience=30, mode='min', min_delta=0.0001)
callbacks = [early, checkpoint]

#use this when you want early stopping
r = model.fit(
  train_generator,
  validation_data=valid_generator,
  epochs=epochs,
  callbacks=callbacks
)
# Out:
# Epoch 1/100
# 119/119 [==============================] - ETA: 0s - loss: 1.4520 - accuracy: 0.9243
# Epoch 1: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 1029s 9s/step - loss: 1.4520 - accuracy: 0.9243 - val_loss: 1.7533 - val_accuracy: 0.9262
# Epoch 2/100
# 119/119 [==============================] - ETA: 0s - loss: 0.8823 - accuracy: 0.9608
# Epoch 2: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 915s 8s/step - loss: 0.8823 - accuracy: 0.9608 - val_loss: 1.0683 - val_accuracy: 0.9524
# Epoch 3/100
# 119/119 [==============================] - ETA: 0s - loss: 0.8514 - accuracy: 0.9638
# Epoch 3: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 886s 7s/step - loss: 0.8514 - accuracy: 0.9638 - val_loss: 1.2547 - val_accuracy: 0.9548
# Epoch 4/100
# 119/119 [==============================] - ETA: 0s - loss: 0.8697 - accuracy: 0.9653
# Epoch 4: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 803s 7s/step - loss: 0.8697 - accuracy: 0.9653 - val_loss: 1.0754 - val_accuracy: 0.9667
# Epoch 5/100
# 119/119 [==============================] - ETA: 0s - loss: 0.9153 - accuracy: 0.9709
# Epoch 5: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 687s 6s/step - loss: 0.9153 - accuracy: 0.9709 - val_loss: 1.2753 - val_accuracy: 0.9595
# Epoch 6/100
# 119/119 [==============================] - ETA: 0s - loss: 0.8658 - accuracy: 0.9741
# Epoch 6: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 688s 6s/step - loss: 0.8658 - accuracy: 0.9741 - val_loss: 1.2018 - val_accuracy: 0.9667
# Epoch 7/100
# 119/119 [==============================] - ETA: 0s - loss: 0.7986 - accuracy: 0.9775
# Epoch 7: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 687s 6s/step - loss: 0.7986 - accuracy: 0.9775 - val_loss: 1.4116 - val_accuracy: 0.9659
# Epoch 8/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6265 - accuracy: 0.9804
# Epoch 8: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 689s 6s/step - loss: 0.6265 - accuracy: 0.9804 - val_loss: 1.2730 - val_accuracy: 0.9627
# Epoch 9/100
# 119/119 [==============================] - ETA: 0s - loss: 0.7788 - accuracy: 0.9767
# Epoch 9: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 686s 6s/step - loss: 0.7788 - accuracy: 0.9767 - val_loss: 1.3081 - val_accuracy: 0.9643
# Epoch 10/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6589 - accuracy: 0.9831
# Epoch 10: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 686s 6s/step - loss: 0.6589 - accuracy: 0.9831 - val_loss: 1.1312 - val_accuracy: 0.9746
# Epoch 11/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6069 - accuracy: 0.9833
# Epoch 11: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 685s 6s/step - loss: 0.6069 - accuracy: 0.9833 - val_loss: 1.0242 - val_accuracy: 0.9730
# Epoch 12/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6616 - accuracy: 0.9841
# Epoch 12: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 686s 6s/step - loss: 0.6616 - accuracy: 0.9841 - val_loss: 1.2724 - val_accuracy: 0.9619
# Epoch 13/100
# 119/119 [==============================] - ETA: 0s - loss: 0.5814 - accuracy: 0.9839
# Epoch 13: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 684s 6s/step - loss: 0.5814 - accuracy: 0.9839 - val_loss: 1.4106 - val_accuracy: 0.9667
# Epoch 14/100
# 119/119 [==============================] - ETA: 0s - loss: 0.8391 - accuracy: 0.9772
# Epoch 14: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 684s 6s/step - loss: 0.8391 - accuracy: 0.9772 - val_loss: 1.0836 - val_accuracy: 0.9722
# Epoch 15/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6551 - accuracy: 0.9876
# Epoch 15: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 684s 6s/step - loss: 0.6551 - accuracy: 0.9876 - val_loss: 1.3006 - val_accuracy: 0.9683
# Epoch 16/100
# 119/119 [==============================] - ETA: 0s - loss: 0.5316 - accuracy: 0.9868
# Epoch 16: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 684s 6s/step - loss: 0.5316 - accuracy: 0.9868 - val_loss: 1.6012 - val_accuracy: 0.9690
# Epoch 17/100
# 119/119 [==============================] - ETA: 0s - loss: 0.5418 - accuracy: 0.9865
# Epoch 17: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 686s 6s/step - loss: 0.5418 - accuracy: 0.9865 - val_loss: 1.8485 - val_accuracy: 0.9587
# Epoch 18/100
# 119/119 [==============================] - ETA: 0s - loss: 0.5167 - accuracy: 0.9857
# Epoch 18: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 684s 6s/step - loss: 0.5167 - accuracy: 0.9857 - val_loss: 1.3889 - val_accuracy: 0.9659
# Epoch 19/100
# 119/119 [==============================] - ETA: 0s - loss: 0.5935 - accuracy: 0.9852
# Epoch 19: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 683s 6s/step - loss: 0.5935 - accuracy: 0.9852 - val_loss: 1.4668 - val_accuracy: 0.9762
# Epoch 20/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6572 - accuracy: 0.9857
# Epoch 20: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 684s 6s/step - loss: 0.6572 - accuracy: 0.9857 - val_loss: 1.5121 - val_accuracy: 0.9683
# Epoch 21/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6429 - accuracy: 0.9857
# Epoch 21: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 684s 6s/step - loss: 0.6429 - accuracy: 0.9857 - val_loss: 1.4530 - val_accuracy: 0.9730
# Epoch 22/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6169 - accuracy: 0.9876
# Epoch 22: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 686s 6s/step - loss: 0.6169 - accuracy: 0.9876 - val_loss: 1.4076 - val_accuracy: 0.9738
# Epoch 23/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6151 - accuracy: 0.9862
# Epoch 23: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 688s 6s/step - loss: 0.6151 - accuracy: 0.9862 - val_loss: 1.8089 - val_accuracy: 0.9706
# Epoch 24/100
# 119/119 [==============================] - ETA: 0s - loss: 0.5142 - accuracy: 0.9876
# Epoch 24: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 692s 6s/step - loss: 0.5142 - accuracy: 0.9876 - val_loss: 1.3446 - val_accuracy: 0.9698
# Epoch 25/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6331 - accuracy: 0.9865
# Epoch 25: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 687s 6s/step - loss: 0.6331 - accuracy: 0.9865 - val_loss: 1.4316 - val_accuracy: 0.9770
# Epoch 26/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6454 - accuracy: 0.9873
# Epoch 26: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 708s 6s/step - loss: 0.6454 - accuracy: 0.9873 - val_loss: 2.6742 - val_accuracy: 0.9667
# Epoch 27/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6115 - accuracy: 0.9876
# Epoch 27: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 680s 6s/step - loss: 0.6115 - accuracy: 0.9876 - val_loss: 2.1105 - val_accuracy: 0.9675
# Epoch 28/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6749 - accuracy: 0.9865
# Epoch 28: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 684s 6s/step - loss: 0.6749 - accuracy: 0.9865 - val_loss: 1.9181 - val_accuracy: 0.9722
# Epoch 29/100
# 119/119 [==============================] - ETA: 0s - loss: 0.4615 - accuracy: 0.9886
# Epoch 29: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 683s 6s/step - loss: 0.4615 - accuracy: 0.9886 - val_loss: 1.3282 - val_accuracy: 0.9770
# Epoch 30/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6286 - accuracy: 0.9881
# Epoch 30: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 681s 6s/step - loss: 0.6286 - accuracy: 0.9881 - val_loss: 1.6041 - val_accuracy: 0.9706
# Epoch 31/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6906 - accuracy: 0.9857
# Epoch 31: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 683s 6s/step - loss: 0.6906 - accuracy: 0.9857 - val_loss: 1.6506 - val_accuracy: 0.9698
# Epoch 32/100
# 119/119 [==============================] - ETA: 0s - loss: 0.8312 - accuracy: 0.9860
# Epoch 32: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 682s 6s/step - loss: 0.8312 - accuracy: 0.9860 - val_loss: 1.9566 - val_accuracy: 0.9706
# Epoch 33/100
# 119/119 [==============================] - ETA: 0s - loss: 0.5090 - accuracy: 0.9915
# Epoch 33: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 684s 6s/step - loss: 0.5090 - accuracy: 0.9915 - val_loss: 2.2184 - val_accuracy: 0.9690
# Epoch 34/100
# 119/119 [==============================] - ETA: 0s - loss: 0.4070 - accuracy: 0.9892
# Epoch 34: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] -


# %% [markdown]
# # Evaluate model

# %%
result_val = model.evaluate(valid_generator,batch_size=batch_size)
print("Validation -> Validation loss, Validation accuracy",result_val)
# Out:
# 40/40 [==============================] - 170s 4s/step - loss: 2.5374 - accuracy: 0.9698
# Validation -> Validation loss, Validation accuracy [2.537442207336426, 0.9698412418365479]

# %%
result_train = model.evaluate(train_generator,batch_size=batch_size)
print("Training -> Training loss, Training accuracy",result_train)
# Out:
# 119/119 [==============================] - 510s 4s/step - loss: 0.6378 - accuracy: 0.9892
# Training -> Training loss, Training accuracy [0.6378482580184937, 0.9891534447669983]

# %%
result = model.evaluate(test_gen,batch_size=batch_size)
print("Testing -> Test loss, Test accuracy",result)
# Out:
# 40/40 [==============================] - 174s 4s/step - loss: 2.1241 - accuracy: 0.9714
# Testing -> Test loss, Test accuracy [2.124065399169922, 0.9714285731315613]

# %% [markdown]
# # Calculating Reality & Predictions

# %% [markdown]
# ## Validation & Testing

# %%
import cv2
import tensorflow as tf # machine learning
from sklearn.metrics import accuracy_score, confusion_matrix
import torch
import torchvision

IMG_SIZE = (224, 224)

def preprocess_imgs(path, img_size):
    set_new = []
    for value in os.listdir(path):
        for img in os.listdir(path + value):
            img = cv2.imread(path + value + "/" + img)
            img = cv2.resize(
                img,
                dsize=img_size,
                interpolation=cv2.INTER_CUBIC
            )
            set_new.append(tf.keras.applications.vgg16.preprocess_input(img))
    
    return np.array(set_new)

valid_data = preprocess_imgs(Validation_path, img_size=IMG_SIZE)

valid_reality = []
for value in os.listdir(Validation_path):
    for img in os.listdir(Validation_path + value):
        valid_reality.append(1) if value.lower() == "snake" else valid_reality.append(0)
        
valid_predictions = model.predict(valid_data)
# predictions = [0 if x > 0.5 else 1 for x in predictions]
valid_predictions = np.argmax(valid_predictions, axis=1)

accuracy = accuracy_score(valid_reality, valid_predictions)
print("Validation Evaluation Done")


test_data = preprocess_imgs(Test_path, img_size=IMG_SIZE)

test_reality = []
for value in os.listdir(Test_path):
    for img in os.listdir(Test_path + value):
        test_reality.append(1) if value.lower() == "snake" else test_reality.append(0)
        
test_predictions = model.predict(test_data)
# predictions = [0 if x > 0.5 else 1 for x in predictions]
test_predictions = np.argmax(test_predictions, axis=1)

accuracy = accuracy_score(test_reality, test_predictions)
print("Testing Evaluation Done")
# Out:
# 40/40 [==============================] - 161s 4s/step
# Validation Evaluation Done
# 40/40 [==============================] - 160s 4s/step
# Testing Evaluation Done

# %% [markdown]
# # Visualization the result

# %% [markdown]
# ## Model Performance Graph

# %%
acc = r.history['accuracy']
val_acc = r.history['val_accuracy']
loss = r.history['loss']
val_loss = r.history['val_loss']

epochs_range = range(1, len(r.epoch) + 1)

#Accuracy
plt.figure(figsize=(10,5))

plt.plot(epochs_range, acc, label='Training')
plt.plot(epochs_range, val_acc, label='Validation')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.tight_layout()
plt.savefig('./saved_RAW/M1A_VGG16/model-acc-graph.png')
plt.show()

#Loss
plt.figure(figsize=(10,5))

plt.plot(epochs_range, loss, label='Training')
plt.plot(epochs_range, val_loss, label='Validation')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.tight_layout()
plt.savefig('./saved_RAW/M1A_VGG16/model-loss-graph.png')
plt.show()

# %% [markdown]
# ## Heatmap

# %% [markdown]
# ### Validation & Testing

# %%
import seaborn as sn

valid_confusion_mtx = confusion_matrix(valid_reality, valid_predictions)

ax = plt.axes()
sn.heatmap(valid_confusion_mtx, annot=True,annot_kws={"size": 25}, cmap="crest", ax = ax, fmt=".1f")
ax.set_title('Validation Accuracy', size=14)
plt.xlabel('Predictions', fontsize=11)
plt.ylabel('Actuals', fontsize=11)
plt.savefig('./saved_RAW/M1A_VGG16/valid-acc-heatmap.png')
plt.show()


test_confusion_mtx = confusion_matrix(test_reality, test_predictions)

ax = plt.axes()
sn.heatmap(test_confusion_mtx, annot=True,annot_kws={"size": 25}, cmap="crest", ax = ax, fmt=".1f")
ax.set_title('Testing Accuracy', size=14)
plt.xlabel('Predictions', fontsize=11)
plt.ylabel('Actuals', fontsize=11)
plt.savefig('./saved_RAW/M1A_VGG16/test-acc-heatmap.png')
plt.show()

# %%
from sklearn.metrics import classification_report

print('Classification Report of Validation \n')
target_names = ['non-snake', 'snake']
print(classification_report(valid_reality,valid_predictions, target_names=target_names))

print('Classification Report of Testing \n')
target_names = ['non-snake', 'snake']
print(classification_report(test_reality,test_predictions, target_names=target_names))
# Out:
# Classification Report of Validation
#
#               precision    recall  f1-score   support
#
#    non-snake       0.93      0.96      0.95       630
#        snake       0.96      0.93      0.95       630
#
#     accuracy                           0.95      1260
#    macro avg       0.95      0.95      0.95      1260
# weighted avg       0.95      0.95      0.95      1260
#
# Classification Report of Testing
#
#               precision    recall  f1-score   support
#
#    non-snake       0.94      0.97      0.95       630
#        snake       0.97      0.94      0.95       630
#
#     accuracy                           0.95      1260
#    macro avg       0.95      0.95      0.95      1260
# weighted avg       0.95      0.95      0.95      1260

# %% [markdown]
# # Evaluation (Accuracy, Precision, Recall, F1-score)

# %% [markdown]
# ## Validation & Testing

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(valid_reality, valid_predictions)
print('Validation Accuracy: %f' % accuracy)

# precision tp / (tp + fp)
precision = precision_score(valid_reality, valid_predictions)
print('Validation Precision: %f' % precision)

# recall: tp / (tp + fn)
recall = recall_score(valid_reality, valid_predictions)
print('Validation Recall: %f' % recall)

# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(valid_reality, valid_predictions)
print('Validation F1 score: %f' % f1)
print('----------------------------------------------------')


# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(test_reality, test_predictions)
print('Testing Accuracy: %f' % accuracy)

# precision tp / (tp + fp)
precision = precision_score(test_reality, test_predictions)
print('Testing Precision: %f' % precision)

# recall: tp / (tp + fn)
recall = recall_score(test_reality, test_predictions)
print('Testing Recall: %f' % recall)

# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(test_reality, test_predictions)
print('Testing F1 score: %f' % f1)
# Out:
# Validation Accuracy: 0.946032
# Validation Precision: 0.960656
# Validation Recall: 0.930159
# Validation F1 score: 0.945161
# ----------------------------------------------------
# Testing Accuracy: 0.953968
# Testing Precision: 0.967320
# Testing Recall: 0.939683
# Testing F1 score: 0.953301

# %% [markdown]
# # Showing wrong prediction images

# %%
from PIL import Image

def check_image(path, img_size, order):
    k = 0
    for value in os.listdir(path):
        for img in os.listdir(path + value):
            if k == order: 
                return img
            k = k+1

# %% [markdown]
# ## Validation

# %%
print('This is the wrong prediction of validation set')
i = 0
for value in valid_predictions:
    if valid_reality[i] != valid_predictions[i]:
        image = check_image(Test_path, img_size=IMG_SIZE, order=i)
        print('reality -> ', valid_reality[i], ' != predictions -> ', valid_predictions[i], ' -----> ', image)
            
    i = i + 1
# Out:
# This is the wrong prediction of validation set
# reality ->  0  != predictions ->  1  ----->  AQU_165.jpg
# reality ->  0  != predictions ->  1  ----->  AQU_427.jpg
# reality ->  0  != predictions ->  1  ----->  AQU_429.jpg
# reality ->  0  != predictions ->  1  ----->  INS_342.jpg
# reality ->  0  != predictions ->  1  ----->  NON_173.jpg
# reality ->  0  != predictions ->  1  ----->  NON_179.jpg
# reality ->  0  != predictions ->  1  ----->  NON_185.jpg
# reality ->  0  != predictions ->  1  ----->  NON_189.jpg
# reality ->  0  != predictions ->  1  ----->  NON_203.jpg
# reality ->  0  != predictions ->  1  ----->  NON_209.jpg
# reality ->  0  != predictions ->  1  ----->  NON_220.jpg
# reality ->  0  != predictions ->  1  ----->  NON_269.jpg
# reality ->  0  != predictions ->  1  ----->  NON_303.jpg
# reality ->  0  != predictions ->  1  ----->  NON_333.jpg
# reality ->  0  != predictions ->  1  ----->  NON_364.jpg
# reality ->  0  != predictions ->  1  ----->  NON_37.jpg
# reality ->  0  != predictions ->  1  ----->  NON_375.jpg
# reality ->  0  != predictions ->  1  ----->  NON_425.jpg
# reality ->  0  != predictions ->  1  ----->  NON_441.jpg
# reality ->  0  != predictions ->  1  ----->  POU_150.jpg
# reality ->  0  != predictions ->  1  ----->  POU_152.jpg
# reality ->  0  != predictions ->  1  ----->  REP_348.jpg
# reality ->  0  != predictions ->  1  ----->  REP_381.jpg
# reality ->  0  != predictions ->  1  ----->  REP_382.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_307.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_342.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_46.jpg
# reality ->  1  != predictions ->  0  ----->  COP_5.jpg
# reality ->  1  != predictions ->  0  ----->  COP_58.jpg
# reality ->  1  != predictions ->  0  ----->  MON_345.jpg
# reality ->  1  != predictions ->  0  ----->  MON_36.jpg
# reality ->  1  != predictions ->  0  ----->  MON_43.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_184.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_345.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_36.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_4.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_55.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_91.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_123.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_265.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_4.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_43.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_53.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_56.jpg
# reality ->  1  != predictions ->  0  ----->  RET_342.jpg
# reality ->  1  != predictions ->  0  ----->  RET_47.jpg
# reality ->  1  != predictions ->  0  ----->  RET_53.jpg
# reality ->  1  != predictions ->  0  ----->  STR_26.jpg
# reality ->  1  != predictions ->  0  ----->  STR_295.jpg
# reality ->  1  != predictions ->  0  ----->  STR_299.jpg
# reality ->  1  != predictions ->  0  ----->  STR_37.jpg
# reality ->  1  != predictions ->  0  ----->  STR_43.jpg
# reality ->  1  != predictions ->  0  ----->  STR_47.jpg
# reality ->  1  != predictions ->  0  ----->  STR_58.jpg
# reality ->  1  != predictions ->  0  ----->  SUN_182.jpg
# reality ->  1  != predictions ->  0  ----->  SUN_36.jpg
# reality ->  1  != predictions ->  0  ----->  SUN_46.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_129.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_147.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_175.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_182.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_220.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_23.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_252.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_261.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_4.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_43.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_5.jpg

# %% [markdown]
# ## Testing set

# %%
print('This is the wrong prediction of testing set')
i = 0
for value in test_predictions:
    if test_reality[i] != test_predictions[i]:
        image = check_image(Test_path, img_size=IMG_SIZE, order=i)
        print('reality -> ', test_reality[i], ' != predictions -> ', test_predictions[i], ' -----> ', image)
            
    i = i + 1
# Out:
# This is the wrong prediction of testing set
# reality ->  0  != predictions ->  1  ----->  AQU_146.jpg
# reality ->  0  != predictions ->  1  ----->  AQU_480.jpg
# reality ->  0  != predictions ->  1  ----->  INS_343.jpg
# reality ->  0  != predictions ->  1  ----->  NON_114.jpg
# reality ->  0  != predictions ->  1  ----->  NON_124.jpg
# reality ->  0  != predictions ->  1  ----->  NON_153.jpg
# reality ->  0  != predictions ->  1  ----->  NON_165.jpg
# reality ->  0  != predictions ->  1  ----->  NON_169.jpg
# reality ->  0  != predictions ->  1  ----->  NON_231.jpg
# reality ->  0  != predictions ->  1  ----->  NON_253.jpg
# reality ->  0  != predictions ->  1  ----->  NON_256.jpg
# reality ->  0  != predictions ->  1  ----->  NON_267.jpg
# reality ->  0  != predictions ->  1  ----->  NON_269.jpg
# reality ->  0  != predictions ->  1  ----->  NON_281.jpg
# reality ->  0  != predictions ->  1  ----->  NON_345.jpg
# reality ->  0  != predictions ->  1  ----->  NON_382.jpg
# reality ->  0  != predictions ->  1  ----->  NON_383.jpg
# reality ->  0  != predictions ->  1  ----->  NON_487.jpg
# reality ->  0  != predictions ->  1  ----->  NON_495.jpg
# reality ->  0  != predictions ->  1  ----->  NON_510.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_23.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_276.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_341.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_56.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_93.jpg
# reality ->  1  != predictions ->  0  ----->  COP_341.jpg
# reality ->  1  != predictions ->  0  ----->  MON_310.jpg
# reality ->  1  != predictions ->  0  ----->  MON_342.jpg
# reality ->  1  != predictions ->  0  ----->  MON_345.jpg
# reality ->  1  != predictions ->  0  ----->  MON_58.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_147.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_310.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_342.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_36.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_37.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_198.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_268.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_307.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_310.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_342.jpg
# reality ->  1  != predictions ->  0  ----->  RET_184.jpg
# reality ->  1  != predictions ->  0  ----->  RET_307.jpg
# reality ->  1  != predictions ->  0  ----->  RET_342.jpg
# reality ->  1  != predictions ->  0  ----->  RET_345.jpg
# reality ->  1  != predictions ->  0  ----->  STR_267.jpg
# reality ->  1  != predictions ->  0  ----->  STR_342.jpg
# reality ->  1  != predictions ->  0  ----->  STR_91.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_153.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_19.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_204.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_212.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_220.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_23.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_267.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_310.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_341.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_342.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_87.jpg

# %% [markdown]
# # Save model after training

# %%
# save model and architecture to single file

model.save("./saved_RAW/M1A_VGG16/VGG16_M1A_model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from tensorflow.keras.models import save_model

save_model(model, "./saved_RAW/M1A_VGG16/VGG16_M1A_model.h5")

# %% [markdown]
# # Guess the input image

# %%
from tensorflow.keras.models import load_model

model = load_model('./saved_RAW/M1A_VGG16/VGG16_M1A_model.h5')

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

test_image = tf.keras.utils.load_img(r'./unknown/BAN_352.jpg', color_mode ='rgb',target_size = (224, 224))
test_image = tf.keras.utils.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)

res = np.argmax(result)

dict1 = {0 : 'non-snake', 1: 'snake'}
print("The predicted output is :",dict1[res])

img = mpimg.imread('./unknown/BAN_352.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# 1/1 [==============================] - 0s 234ms/step
# The predicted output is : snake

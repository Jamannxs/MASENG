# %% [markdown]
# https://github.com/jhanwarakhil/vgg16_transfer_learning/blob/master/vgg_16_fruits.ipynb

# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg19 import VGG19
from keras.applications.vgg19 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import image_utils
import numpy as np

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline
from glob import glob

# %%
# import zipfile as zf #use for unzip files and keep in the same folder w/ manually combine into 1 folder

# # files1 = zf.ZipFile("snake.zip",'r')
# # files1.extractall()
# # files1.close()

# # files2 = zf.ZipFile("non-snake.zip",'r')
# # files2.extractall()
# # files2.close()

# files = zf.ZipFile("dataset.zip",'r')
# files.extractall()
# files.close()

# %%
# import splitfolders

# splitfolders.ratio("dataset", output="output", seed=1337, ratio=(.6, .2, .2), group_prefix=None, move=False)

# %%
IMAGE_SIZE = [224, 224] 

# training config:
epochs = 100 #One Epoch is when an Enter dataset is passed forward and backward through the neural network only once
batch_size = 32 #no. of the images that go in each round/ divide dataset into number of batches or set

# %%
train_path = './output_M1A/train'
valid_path = './output_M1A/val'
test_path = './output_M1A/test' #**************************

# %%
Training_path = './output_M1A/train/'
Validation_path = './output_M1A/val/'
Test_path = './output_M1A/test/'

# %%
import os

def number_of_imgs(path):
    print(path)
    for value in os.listdir(path):
        print(value, "has", len(os.listdir(path + value)), "imgs")
    print('\n')
    
    
number_of_imgs(Test_path)
number_of_imgs(Training_path)
number_of_imgs(Validation_path)
# Out:
# ./output_M1A/test/
# non-snake has 630 imgs
# snake has 630 imgs
#
#
# ./output_M1A/train/
# non-snake has 1890 imgs
# snake has 1890 imgs
#
#
# ./output_M1A/val/
# non-snake has 630 imgs
# snake has 630 imgs

# %%
image_files = glob(train_path + '/*/*.jp*g')
valid_image_files = glob(valid_path + '/*/*.jp*g')

# useful for getting number of classes
folders = glob(train_path + '/*')

print(len(image_files))
# Out:
# 3779

# %%
def create_dataframe(path):
    data = []
    for value in os.listdir(path):
        for image in os.listdir(path + value + "/"):
            file_path = path + value + "/" + image
            # if snake than set if to 1 else 0
            snake = 1 if value.lower() == "snake" else 0
            data.append({"path": file_path, 'snake': snake})
            
    df = pd.DataFrame(data=data).sample(frac=1).reset_index(drop=True)

    return df

# %%
# %matplotlib inline
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def plot_imgs(title, paths):
    fig = plt.figure(figsize=(14, 8), dpi=72)
    fig.suptitle(title, fontsize=24, y=1.05)
    for i, row in paths.iterrows():
        img=mpimg.imread(row['path'])
        plt.subplot(3, 5, i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        subtitle = 'YES' if row['snake'] == 1 else 'NO'
        plt.title(subtitle)
        plt.imshow(img)
    plt.tight_layout()
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None)
    plt.show()
    
    
plot_imgs("Test", create_dataframe(Test_path).sample(15).reset_index(drop=True))
plot_imgs("Train", create_dataframe(Training_path).sample(15).reset_index(drop=True))
plot_imgs("Validation", create_dataframe(Validation_path).sample(15).reset_index(drop=True))

# %% [markdown]
# # Start VGG model

# %%
vgg=VGG19(include_top=False,weights='imagenet',input_shape=(224,224,3))

# %%
for layer in vgg.layers:
    layer.trainable =False

# %%
x=Flatten()(vgg.output)
prediction=Dense(len(folders),activation='softmax')(x)
model=Model(inputs=vgg.input,outputs=prediction)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 2)                 50178
#
# =================================================================
# Total params: 20,074,562
# Trainable params: 50,178
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %% [markdown]
# # Optimizer: rmsprop, SDG, adam, adadelta, adagrad, adamax, nadam, ftrl

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
gen=ImageDataGenerator(rotation_range=20,width_shift_range=0.1,height_shift_range=0.1,shear_range=0.1,zoom_range=0.2,horizontal_flip=True,vertical_flip=True,preprocessing_function=preprocess_input)

# %%
test_gen=gen.flow_from_directory(test_path,target_size=IMAGE_SIZE)
# Out:
# Found 1260 images belonging to 2 classes.

# %%
labels = [None] * len(test_gen.class_indices)
print(labels)
for k, v in test_gen.class_indices.items():
  labels[v] = k
print(labels[0])
# Out:
# [None, None]
# non-snake

# %%
for x, y in test_gen:
  print("min:", x[0].min(), "max:", x[0].max())
  print(y[0])
  plt.title(labels[np.argmax(y[0])])
  plt.imshow(x[0])
  plt.show()
  break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# min: -123.64702 max: 104.92089
# [0. 1.]

# %%
train_generator = gen.flow_from_directory(
  train_path,
  target_size=IMAGE_SIZE,
  shuffle=True,
  batch_size=batch_size,
)
valid_generator = gen.flow_from_directory(
  valid_path,
  target_size=IMAGE_SIZE,
  shuffle=True,
  batch_size=batch_size,
)
# Out:
# Found 3780 images belonging to 2 classes.
# Found 1260 images belonging to 2 classes.

# %% [markdown]
# ### Model.fit version 1 for specific epochs

# %%
# #if you run version 2, do not run this cell

# # download
# import imageio
# imageio.plugins.freeimage.download()

# r = model.fit(
#   train_generator,
#   validation_data=valid_generator,
#   epochs=epochs
# )

# %% [markdown]
# ### Model.fit version 2 for avg epochs (early stopping)

# %%
#if you want to run version 1, do not run this cell

#create callback + early stopping 
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

filepath = './saved_RAW/M1A_VGG19/VGG19_M1A_model.hdf5'
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_loss', verbose=1, save_weights_only=True, mode='min')
early = EarlyStopping(monitor='val_loss', patience=30, mode='min', min_delta=0.0001)
callbacks = [early, checkpoint]

#use this when you want early stopping
r = model.fit(
  train_generator,
  validation_data=valid_generator,
  epochs=epochs,
  callbacks=callbacks
)
# Out:
# Epoch 1/100
# 119/119 [==============================] - ETA: 0s - loss: 1.3281 - accuracy: 0.9262
# Epoch 1: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 846s 7s/step - loss: 1.3281 - accuracy: 0.9262 - val_loss: 1.1814 - val_accuracy: 0.9429
# Epoch 2/100
# 119/119 [==============================] - ETA: 0s - loss: 0.9910 - accuracy: 0.9571
# Epoch 2: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 834s 7s/step - loss: 0.9910 - accuracy: 0.9571 - val_loss: 1.4218 - val_accuracy: 0.9484
# Epoch 3/100
# 119/119 [==============================] - ETA: 0s - loss: 0.8780 - accuracy: 0.9603
# Epoch 3: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 837s 7s/step - loss: 0.8780 - accuracy: 0.9603 - val_loss: 1.0761 - val_accuracy: 0.9579
# Epoch 4/100
# 119/119 [==============================] - ETA: 0s - loss: 0.8799 - accuracy: 0.9672
# Epoch 4: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 838s 7s/step - loss: 0.8799 - accuracy: 0.9672 - val_loss: 1.3194 - val_accuracy: 0.9500
# Epoch 5/100
# 119/119 [==============================] - ETA: 0s - loss: 0.7930 - accuracy: 0.9709
# Epoch 5: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 839s 7s/step - loss: 0.7930 - accuracy: 0.9709 - val_loss: 1.5812 - val_accuracy: 0.9571
# Epoch 6/100
# 119/119 [==============================] - ETA: 0s - loss: 0.7528 - accuracy: 0.9730
# Epoch 6: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 837s 7s/step - loss: 0.7528 - accuracy: 0.9730 - val_loss: 1.1797 - val_accuracy: 0.9635
# Epoch 7/100
# 119/119 [==============================] - ETA: 0s - loss: 0.8386 - accuracy: 0.9722
# Epoch 7: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 838s 7s/step - loss: 0.8386 - accuracy: 0.9722 - val_loss: 1.2126 - val_accuracy: 0.9627
# Epoch 8/100
# 119/119 [==============================] - ETA: 0s - loss: 0.7017 - accuracy: 0.9775
# Epoch 8: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 837s 7s/step - loss: 0.7017 - accuracy: 0.9775 - val_loss: 1.0928 - val_accuracy: 0.9690
# Epoch 9/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6318 - accuracy: 0.9812
# Epoch 9: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 839s 7s/step - loss: 0.6318 - accuracy: 0.9812 - val_loss: 1.5995 - val_accuracy: 0.9595
# Epoch 10/100
# 119/119 [==============================] - ETA: 0s - loss: 0.8199 - accuracy: 0.9772
# Epoch 10: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 839s 7s/step - loss: 0.8199 - accuracy: 0.9772 - val_loss: 1.4156 - val_accuracy: 0.9690
# Epoch 11/100
# 119/119 [==============================] - ETA: 0s - loss: 0.7849 - accuracy: 0.9775
# Epoch 11: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 835s 7s/step - loss: 0.7849 - accuracy: 0.9775 - val_loss: 1.7246 - val_accuracy: 0.9595
# Epoch 12/100
# 119/119 [==============================] - ETA: 0s - loss: 0.8885 - accuracy: 0.9762
# Epoch 12: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 837s 7s/step - loss: 0.8885 - accuracy: 0.9762 - val_loss: 2.0936 - val_accuracy: 0.9532
# Epoch 13/100
# 119/119 [==============================] - ETA: 0s - loss: 0.9009 - accuracy: 0.9757
# Epoch 13: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 840s 7s/step - loss: 0.9009 - accuracy: 0.9757 - val_loss: 1.8851 - val_accuracy: 0.9611
# Epoch 14/100
# 119/119 [==============================] - ETA: 0s - loss: 0.7585 - accuracy: 0.9794
# Epoch 14: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 834s 7s/step - loss: 0.7585 - accuracy: 0.9794 - val_loss: 1.6499 - val_accuracy: 0.9627
# Epoch 15/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6569 - accuracy: 0.9799
# Epoch 15: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 835s 7s/step - loss: 0.6569 - accuracy: 0.9799 - val_loss: 2.0079 - val_accuracy: 0.9571
# Epoch 16/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6191 - accuracy: 0.9825
# Epoch 16: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 837s 7s/step - loss: 0.6191 - accuracy: 0.9825 - val_loss: 1.7044 - val_accuracy: 0.9690
# Epoch 17/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6235 - accuracy: 0.9836
# Epoch 17: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 842s 7s/step - loss: 0.6235 - accuracy: 0.9836 - val_loss: 1.6233 - val_accuracy: 0.9667
# Epoch 18/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6942 - accuracy: 0.9815
# Epoch 18: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 835s 7s/step - loss: 0.6942 - accuracy: 0.9815 - val_loss: 2.1140 - val_accuracy: 0.9611
# Epoch 19/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6379 - accuracy: 0.9847
# Epoch 19: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 837s 7s/step - loss: 0.6379 - accuracy: 0.9847 - val_loss: 2.1802 - val_accuracy: 0.9595
# Epoch 20/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6009 - accuracy: 0.9862
# Epoch 20: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 837s 7s/step - loss: 0.6009 - accuracy: 0.9862 - val_loss: 1.8469 - val_accuracy: 0.9643
# Epoch 21/100
# 119/119 [==============================] - ETA: 0s - loss: 0.7535 - accuracy: 0.9839
# Epoch 21: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 837s 7s/step - loss: 0.7535 - accuracy: 0.9839 - val_loss: 2.5138 - val_accuracy: 0.9667
# Epoch 22/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6605 - accuracy: 0.9862
# Epoch 22: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 835s 7s/step - loss: 0.6605 - accuracy: 0.9862 - val_loss: 2.7215 - val_accuracy: 0.9571
# Epoch 23/100
# 119/119 [==============================] - ETA: 0s - loss: 0.5921 - accuracy: 0.9860
# Epoch 23: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 834s 7s/step - loss: 0.5921 - accuracy: 0.9860 - val_loss: 2.4747 - val_accuracy: 0.9619
# Epoch 24/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6470 - accuracy: 0.9870
# Epoch 24: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 834s 7s/step - loss: 0.6470 - accuracy: 0.9870 - val_loss: 1.8450 - val_accuracy: 0.9651
# Epoch 25/100
# 119/119 [==============================] - ETA: 0s - loss: 0.5608 - accuracy: 0.9865
# Epoch 25: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 836s 7s/step - loss: 0.5608 - accuracy: 0.9865 - val_loss: 1.8136 - val_accuracy: 0.9635
# Epoch 26/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6763 - accuracy: 0.9870
# Epoch 26: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 836s 7s/step - loss: 0.6763 - accuracy: 0.9870 - val_loss: 3.1312 - val_accuracy: 0.9548
# Epoch 27/100
# 119/119 [==============================] - ETA: 0s - loss: 0.5974 - accuracy: 0.9865
# Epoch 27: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 835s 7s/step - loss: 0.5974 - accuracy: 0.9865 - val_loss: 2.5792 - val_accuracy: 0.9619
# Epoch 28/100
# 119/119 [==============================] - ETA: 0s - loss: 0.7334 - accuracy: 0.9831
# Epoch 28: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 835s 7s/step - loss: 0.7334 - accuracy: 0.9831 - val_loss: 2.6753 - val_accuracy: 0.9651
# Epoch 29/100
# 119/119 [==============================] - ETA: 0s - loss: 0.6976 - accuracy: 0.9836
# Epoch 29: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 834s 7s/step - loss: 0.6976 - accuracy: 0.9836 - val_loss: 2.4243 - val_accuracy: 0.9603
# Epoch 30/100
# 119/119 [==============================] - ETA: 0s - loss: 0.7025 - accuracy: 0.9839
# Epoch 30: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 839s 7s/step - loss: 0.7025 - accuracy: 0.9839 - val_loss: 2.3021 - val_accuracy: 0.9659
# Epoch 31/100
# 119/119 [==============================] - ETA: 0s - loss: 0.5354 - accuracy: 0.9870
# Epoch 31: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 838s 7s/step - loss: 0.5354 - accuracy: 0.9870 - val_loss: 2.2241 - val_accuracy: 0.9690
# Epoch 32/100
# 119/119 [==============================] - ETA: 0s - loss: 0.5695 - accuracy: 0.9878
# Epoch 32: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 876s 7s/step - loss: 0.5695 - accuracy: 0.9878 - val_loss: 2.6321 - val_accuracy: 0.9667
# Epoch 33/100
# 119/119 [==============================] - ETA: 0s - loss: 0.4364 - accuracy: 0.9905
# Epoch 33: saving model to ./saved_RAW/M1A_VGG16\VGG16_M1A_model.hdf5
# 119/119 [==============================] - 886s 7s/step - loss: 0.4364 - accuracy: 0.9905 - val_loss: 2.4743 - val_accuracy: 0.9619

# %%
print ('Training Accuracy = ' + str(r.history['accuracy']))
print ('Validation Accuracy = ' + str(r.history['val_accuracy']))
# Out:
# Training Accuracy = [0.9261904954910278, 0.9571428298950195, 0.9603174328804016, 0.9671957492828369, 0.9708994626998901, 0.9730158448219299, 0.9722222089767456, 0.9775132536888123, 0.9812169075012207, 0.9772486686706543, 0.9775132536888123, 0.976190447807312, 0.9756613969802856, 0.9793650507926941, 0.9798941612243652, 0.9825396537780762, 0.9835978746414185, 0.9814814925193787, 0.9846560955047607, 0.9862433671951294, 0.9838624596595764, 0.9862433671951294, 0.9859788417816162, 0.9870370626449585, 0.9865079522132874, 0.9870370626449585, 0.9865079522132874, 0.9830687642097473, 0.9835978746414185, 0.9838624596595764, 0.9870370626449585, 0.9878306984901428, 0.9904761910438538]
# Validation Accuracy = [0.9428571462631226, 0.9484127163887024, 0.9579365253448486, 0.949999988079071, 0.9571428298950195, 0.9634920358657837, 0.9626984000205994, 0.9690476059913635, 0.9595237970352173, 0.9690476059913635, 0.9595237970352173, 0.9531745910644531, 0.9611111283302307, 0.9626984000205994, 0.9571428298950195, 0.9690476059913635, 0.9666666388511658, 0.9611111283302307, 0.9595237970352173, 0.9642857313156128, 0.9666666388511658, 0.9571428298950195, 0.961904764175415, 0.9650793671607971, 0.9634920358657837, 0.9547619223594666, 0.961904764175415, 0.9650793671607971, 0.9603174328804016, 0.9658730030059814, 0.9690476059913635, 0.9666666388511658, 0.961904764175415]

# %% [markdown]
# # Evaluate model

# %%
result_val = model.evaluate(valid_generator,batch_size=batch_size)
print("Validation -> Validation loss, Validation accuracy",result_val)
# Out:
# 40/40 [==============================] - 214s 5s/step - loss: 2.1364 - accuracy: 0.9683
# Validation -> Validation loss, Validation accuracy [2.136413097381592, 0.9682539701461792]

# %%
result_train = model.evaluate(train_generator,batch_size=batch_size)
print("Training -> Training loss, Training accuracy",result_train)
# Out:
# 119/119 [==============================] - 631s 5s/step - loss: 0.6636 - accuracy: 0.9870
# Training -> Training loss, Training accuracy [0.6635530591011047, 0.9870370626449585]

# %%
result = model.evaluate(test_gen,batch_size=batch_size)
print("Testing -> Test loss, Test accuracy",result)
# Out:
# 40/40 [==============================] - 212s 5s/step - loss: 2.0651 - accuracy: 0.9667
# Testing -> Test loss, Test accuracy [2.0650978088378906, 0.9666666388511658]

# %% [markdown]
# # Calculating Reality & Predictions

# %% [markdown]
# ## Validation & Testing

# %%
import cv2
import tensorflow as tf # machine learning
from sklearn.metrics import accuracy_score, confusion_matrix
import torch
import torchvision

IMG_SIZE = (224, 224)

def preprocess_imgs(path, img_size):
    set_new = []
    for value in os.listdir(path):
        for img in os.listdir(path + value):
            img = cv2.imread(path + value + "/" + img)
            img = cv2.resize(
                img,
                dsize=img_size,
                interpolation=cv2.INTER_CUBIC
            )
            set_new.append(tf.keras.applications.vgg19.preprocess_input(img))
    
    return np.array(set_new)

valid_data = preprocess_imgs(Validation_path, img_size=IMG_SIZE)

valid_reality = []
for value in os.listdir(Validation_path):
    for img in os.listdir(Validation_path + value):
        valid_reality.append(1) if value.lower() == "snake" else valid_reality.append(0)
        
valid_predictions = model.predict(valid_data)
# predictions = [0 if x > 0.5 else 1 for x in predictions]
valid_predictions = np.argmax(valid_predictions, axis=1)

accuracy = accuracy_score(valid_reality, valid_predictions)
print("Validation Evaluation Done")


test_data = preprocess_imgs(Test_path, img_size=IMG_SIZE)

test_reality = []
for value in os.listdir(Test_path):
    for img in os.listdir(Test_path + value):
        test_reality.append(1) if value.lower() == "snake" else test_reality.append(0)
        
test_predictions = model.predict(test_data)
# predictions = [0 if x > 0.5 else 1 for x in predictions]
test_predictions = np.argmax(test_predictions, axis=1)

accuracy = accuracy_score(test_reality, test_predictions)
print("Testing Evaluation Done")
# Out:
# 40/40 [==============================] - 199s 5s/step
# Validation Evaluation Done
# 40/40 [==============================] - 199s 5s/step
# Testing Evaluation Done

# %% [markdown]
# # Visualization the result

# %% [markdown]
# ## Model Performance Graph

# %%
acc = r.history['accuracy']
val_acc = r.history['val_accuracy']
loss = r.history['loss']
val_loss = r.history['val_loss']

epochs_range = range(1, len(r.epoch) + 1)

#Accuracy
plt.figure(figsize=(10,5))

plt.plot(epochs_range, acc, label='Training')
plt.plot(epochs_range, val_acc, label='Validation')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.tight_layout()
plt.savefig('./saved_RAW/M1A_VGG19/model-acc-graph.png')
plt.show()

#Loss
plt.figure(figsize=(10,5))

plt.plot(epochs_range, loss, label='Training')
plt.plot(epochs_range, val_loss, label='Validation')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.tight_layout()
plt.savefig('./saved_RAW/M1A_VGG19/model-loss-graph.png')
plt.show()

# %% [markdown]
# ## Heatmap

# %% [markdown]
# ### Validation & Testing

# %%
import seaborn as sn

valid_confusion_mtx = confusion_matrix(valid_reality, valid_predictions)

ax = plt.axes()
sn.heatmap(valid_confusion_mtx, annot=True,annot_kws={"size": 25}, cmap="crest", ax = ax, fmt=".1f")
ax.set_title('Validation Accuracy', size=14)
plt.xlabel('Predictions', fontsize=11)
plt.ylabel('Actuals', fontsize=11)
plt.savefig('./saved_RAW/M1A_VGG19/valid-acc-heatmap.png')
plt.show()


test_confusion_mtx = confusion_matrix(test_reality, test_predictions)

ax = plt.axes()
sn.heatmap(test_confusion_mtx, annot=True,annot_kws={"size": 25}, cmap="crest", ax = ax, fmt=".1f")
ax.set_title('Testing Accuracy', size=14)
plt.xlabel('Predictions', fontsize=11)
plt.ylabel('Actuals', fontsize=11)
plt.savefig('./saved_RAW/M1A_VGG19/test-acc-heatmap.png')
plt.show()

# %%
from sklearn.metrics import classification_report

print('Classification Report of Validation \n')
target_names = ['non-snake', 'snake']
print(classification_report(valid_reality,valid_predictions, target_names=target_names))

print('Classification Report of Testing \n')
target_names = ['non-snake', 'snake']
print(classification_report(test_reality,test_predictions, target_names=target_names))
# Out:
# Classification Report of Validation
#
#               precision    recall  f1-score   support
#
#    non-snake       0.93      0.98      0.95       630
#        snake       0.98      0.92      0.95       630
#
#     accuracy                           0.95      1260
#    macro avg       0.95      0.95      0.95      1260
# weighted avg       0.95      0.95      0.95      1260
#
# Classification Report of Testing
#
#               precision    recall  f1-score   support
#
#    non-snake       0.93      0.98      0.96       630
#        snake       0.98      0.92      0.95       630
#
#     accuracy                           0.95      1260
#    macro avg       0.96      0.95      0.95      1260
# weighted avg       0.96      0.95      0.95      1260

# %% [markdown]
# # Evaluation (Accuracy, Precision, Recall, F1-score)

# %% [markdown]
# ## Validation & Testing

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(valid_reality, valid_predictions)
print('Validation Accuracy: %f' % accuracy)

# precision tp / (tp + fp)
precision = precision_score(valid_reality, valid_predictions)
print('Validation Precision: %f' % precision)

# recall: tp / (tp + fn)
recall = recall_score(valid_reality, valid_predictions)
print('Validation Recall: %f' % recall)

# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(valid_reality, valid_predictions)
print('Validation F1 score: %f' % f1)
print('----------------------------------------------------')


# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(test_reality, test_predictions)
print('Testing Accuracy: %f' % accuracy)

# precision tp / (tp + fp)
precision = precision_score(test_reality, test_predictions)
print('Testing Precision: %f' % precision)

# recall: tp / (tp + fn)
recall = recall_score(test_reality, test_predictions)
print('Testing Recall: %f' % recall)

# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(test_reality, test_predictions)
print('Testing F1 score: %f' % f1)
# Out:
# Validation Accuracy: 0.951587
# Validation Precision: 0.978151
# Validation Recall: 0.923810
# Validation F1 score: 0.950204
# ----------------------------------------------------
# Testing Accuracy: 0.953968
# Testing Precision: 0.983108
# Testing Recall: 0.923810
# Testing F1 score: 0.952537

# %% [markdown]
# # Showing wrong prediction images

# %%
from PIL import Image

def check_image(path, img_size, order):
    k = 0
    for value in os.listdir(path):
        for img in os.listdir(path + value):
            if k == order: 
                return img
            k = k+1

# %% [markdown]
# ## Validation

# %%
print('This is the wrong prediction of validation set')
i = 0
for value in valid_predictions:
    if valid_reality[i] != valid_predictions[i]:
        image = check_image(Test_path, img_size=IMG_SIZE, order=i)
        print('reality -> ', valid_reality[i], ' != predictions -> ', valid_predictions[i], ' -----> ', image)
            
    i = i + 1
# Out:
# This is the wrong prediction of validation set
# reality ->  0  != predictions ->  1  ----->  AQU_165.jpg
# reality ->  0  != predictions ->  1  ----->  INS_342.jpg
# reality ->  0  != predictions ->  1  ----->  INS_343.jpg
# reality ->  0  != predictions ->  1  ----->  NON_173.jpg
# reality ->  0  != predictions ->  1  ----->  NON_209.jpg
# reality ->  0  != predictions ->  1  ----->  NON_333.jpg
# reality ->  0  != predictions ->  1  ----->  NON_364.jpg
# reality ->  0  != predictions ->  1  ----->  POU_97.jpg
# reality ->  0  != predictions ->  1  ----->  REP_348.jpg
# reality ->  0  != predictions ->  1  ----->  REP_350.jpg
# reality ->  0  != predictions ->  1  ----->  REP_381.jpg
# reality ->  0  != predictions ->  1  ----->  REP_382.jpg
# reality ->  0  != predictions ->  1  ----->  REP_514.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_307.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_342.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_46.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_58.jpg
# reality ->  1  != predictions ->  0  ----->  COP_184.jpg
# reality ->  1  != predictions ->  0  ----->  COP_47.jpg
# reality ->  1  != predictions ->  0  ----->  COP_58.jpg
# reality ->  1  != predictions ->  0  ----->  MON_37.jpg
# reality ->  1  != predictions ->  0  ----->  MON_47.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_175.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_295.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_345.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_37.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_4.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_55.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_56.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_69.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_7.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_37.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_4.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_56.jpg
# reality ->  1  != predictions ->  0  ----->  RET_267.jpg
# reality ->  1  != predictions ->  0  ----->  RET_342.jpg
# reality ->  1  != predictions ->  0  ----->  RET_36.jpg
# reality ->  1  != predictions ->  0  ----->  RET_47.jpg
# reality ->  1  != predictions ->  0  ----->  RET_58.jpg
# reality ->  1  != predictions ->  0  ----->  STR_261.jpg
# reality ->  1  != predictions ->  0  ----->  STR_295.jpg
# reality ->  1  != predictions ->  0  ----->  STR_299.jpg
# reality ->  1  != predictions ->  0  ----->  STR_43.jpg
# reality ->  1  != predictions ->  0  ----->  STR_47.jpg
# reality ->  1  != predictions ->  0  ----->  STR_58.jpg
# reality ->  1  != predictions ->  0  ----->  STR_7.jpg
# reality ->  1  != predictions ->  0  ----->  SUN_182.jpg
# reality ->  1  != predictions ->  0  ----->  SUN_5.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_104.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_107.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_153.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_175.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_193.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_212.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_220.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_252.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_299.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_4.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_43.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_5.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_91.jpg

# %% [markdown]
# ## Testing set

# %%
print('This is the wrong prediction of testing set')
i = 0
for value in test_predictions:
    if test_reality[i] != test_predictions[i]:
        image = check_image(Test_path, img_size=IMG_SIZE, order=i)
        print('reality -> ', test_reality[i], ' != predictions -> ', test_predictions[i], ' -----> ', image)
            
    i = i + 1
# Out:
# This is the wrong prediction of testing set
# reality ->  0  != predictions ->  1  ----->  AQU_244.jpg
# reality ->  0  != predictions ->  1  ----->  INS_342.jpg
# reality ->  0  != predictions ->  1  ----->  INS_343.jpg
# reality ->  0  != predictions ->  1  ----->  NON_124.jpg
# reality ->  0  != predictions ->  1  ----->  NON_131.jpg
# reality ->  0  != predictions ->  1  ----->  NON_189.jpg
# reality ->  0  != predictions ->  1  ----->  NON_231.jpg
# reality ->  0  != predictions ->  1  ----->  NON_269.jpg
# reality ->  0  != predictions ->  1  ----->  NON_495.jpg
# reality ->  0  != predictions ->  1  ----->  REP_524.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_212.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_23.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_276.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_345.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_4.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_56.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_77.jpg
# reality ->  1  != predictions ->  0  ----->  BAN_93.jpg
# reality ->  1  != predictions ->  0  ----->  MON_310.jpg
# reality ->  1  != predictions ->  0  ----->  MON_331.jpg
# reality ->  1  != predictions ->  0  ----->  MON_341.jpg
# reality ->  1  != predictions ->  0  ----->  MON_342.jpg
# reality ->  1  != predictions ->  0  ----->  MON_345.jpg
# reality ->  1  != predictions ->  0  ----->  MON_58.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_204.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_242.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_261.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_310.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_342.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_36.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_53.jpg
# reality ->  1  != predictions ->  0  ----->  ORI_55.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_198.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_307.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_310.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_331.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_341.jpg
# reality ->  1  != predictions ->  0  ----->  ORN_342.jpg
# reality ->  1  != predictions ->  0  ----->  RET_268.jpg
# reality ->  1  != predictions ->  0  ----->  RET_341.jpg
# reality ->  1  != predictions ->  0  ----->  STR_265.jpg
# reality ->  1  != predictions ->  0  ----->  STR_267.jpg
# reality ->  1  != predictions ->  0  ----->  STR_287.jpg
# reality ->  1  != predictions ->  0  ----->  STR_91.jpg
# reality ->  1  != predictions ->  0  ----->  SUN_5.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_104.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_153.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_182.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_19.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_23.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_287.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_310.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_341.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_342.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_4.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_5.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_7.jpg
# reality ->  1  != predictions ->  0  ----->  WHI_9.jpg

# %% [markdown]
# # Save model after training

# %%
# save model and architecture to single file

model.save("./saved_RAW/M1A_VGG19/VGG19_M1A_model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from tensorflow.keras.models import save_model

save_model(model, "./saved_RAW/M1A_VGG19/VGG19_M1A_model.h5")

# %% [markdown]
# # Guess the input image

# %%
from tensorflow.keras.models import load_model

model = load_model('./saved_RAW/M1A_VGG19/VGG19_M1A_model.h5')

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

test_image = tf.keras.utils.load_img(r'./unknown/BAN_352.jpg', color_mode ='rgb',target_size = (224, 224))
test_image = tf.keras.utils.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)

res = np.argmax(result)

dict1 = {0 : 'non-snake', 1: 'snake'}
print("The predicted output is :",dict1[res])

img = mpimg.imread('./unknown/BAN_352.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# 1/1 [==============================] - 0s 297ms/step
# The predicted output is : non-snake

# %% [markdown]
# # This is for evaluating the best model

# %% [markdown]
# ## Dataset: unknown

# %% [markdown]
# ### M1 - Resnet50 (AUG)

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import load_model

# Load the trained model
binary_model = load_model('./model/Resnet50_M1A_AUG_model.h5')
multiclass_model = load_model('./model/Resnet50_M1B_AUG_model.h5')

#define the path of testing set
Test_path = './unknown_eval/'

#create reality list
reality = []
for value in os.listdir(Test_path):
    for img in os.listdir(Test_path + value):
        
        if value.lower() == "c01":
            reality.append(0)

        elif value.lower() == "c02":
            reality.append(1)

        elif value.lower() == "c03":
            reality.append(2)

        elif value.lower() == "c04":
            reality.append(3)

        elif value.lower() == "c05":
            reality.append(4)

        elif value.lower() == "c06":
            reality.append(5)

        elif value.lower() == "c07":
            reality.append(6)

        elif value.lower() == "c08":
            reality.append(7)
            
        elif value.lower() == "c09":
            reality.append(8)

        else: 
            reality.append(9)


# Define the dictionary mapping the snake or not indices to the class names
snake_check = {0: 'non-snake', 1: 'snake'}

# Define the dictionary mapping the species class indices to the class names
species_names = {0: 'c01 - Chrysopelea ornata',
               1: 'c02 - Trimeresurus albolabris',
               2: 'c03 - Oligodon taeniatus',
               3: 'c04 - Coelognathus radiatus',
               4: 'c05 - Oligodon fasciolatus',
               5: 'c06 - Ptyas mucosa',
               6: 'c07 - Xenopeltis unicolor',
               7: 'c08 - Malayopython reticulatus',
               8: 'c09 - Naja kaouthia'}

# Set the directory of the images to be tested
test_dir = './unknown/'

#create prediction list
predictions = []

# Loop through each image file in the directory
for filename in os.listdir(test_dir):
    if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.jpeg'):
        # Load the image
        img_path = os.path.join(test_dir, filename)
        img = tf.keras.utils.load_img(img_path, color_mode='rgb', target_size=(224, 224))
        img_array = tf.keras.utils.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)

        # Apply the prediction model
        prediction = binary_model.predict(img_array)
        predicted_check = np.argmax(prediction)
        
        if predicted_check == 0:
            # Print the predicted class
            print('Image file:', filename)
            print('Predicted class:', snake_check[predicted_check])
            print('********************************************************************')
            
            predictions.append(9)
          
        else:
             # Apply the prediction model
            prediction = multiclass_model.predict(img_array)
            predicted_class = np.argmax(prediction)
            
            # Print the predicted class
            print('Image file:', filename)
            print('Predicted class:', species_names[predicted_class])
            print('********************************************************************')
            
            predictions.append(predicted_class)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# Image file: C01_ORN_351.png
# Predicted class: c01 - Chrysopelea ornata
# ********************************************************************
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 126ms/step
# Image file: C01_ORN_352.png
# Predicted class: c01 - Chrysopelea ornata
# ********************************************************************
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 127ms/step
# Image file: C01_ORN_353.png
# Predicted class: c01 - Chrysopelea ornata
# ********************************************************************
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 109ms/step
# Image file: C01_ORN_354.png
# Predicted class: c03 - Oligodon taeniatus
# ********************************************************************
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 101ms/step
# Image file: C01_ORN_355.png
# Predicted class: c06 - Ptyas mucosa
# ********************************************************************
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 104ms/step
# Image file: C01_ORN_356.png
# Predicted class: c01 - Chrysopelea ornata
# ********************************************************************
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 105ms/step
# Image file: C01_ORN_357.png
# Predicted class: c01 - Chrysopelea ornata
# ********************************************************************
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 108ms/step
# Image file: C01_ORN_358.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 103ms/step
# Image file: C01_ORN_359.png
# Predicted class: c01 - Chrysopelea ornata
# ********************************************************************
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 105ms/step
# Image file: C01_ORN_360.png
# Predicted class: c01 - Chrysopelea ornata
# ********************************************************************
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 99ms/step
# Image file: C02_WHI_351.jpg
# Predicted class: c02 - Trimeresurus albolabris
# ********************************************************************
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 106ms/step
# Image file: C02_WHI_352.jpg
# Predicted class: c02 - Trimeresurus albolabris
# ********************************************************************
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 103ms/step
# Image file: C02_WHI_353.jpg
# Predicted class: c02 - Trimeresurus albolabris
# ********************************************************************
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 104ms/step
# Image file: C02_WHI_354.png
# Predicted class: c02 - Trimeresurus albolabris
# ********************************************************************
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 102ms/step
# Image file: C02_WHI_355.png
# Predicted class: c02 - Trimeresurus albolabris
# ********************************************************************
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 107ms/step
# Image file: C02_WHI_356.png
# Predicted class: c02 - Trimeresurus albolabris
# ********************************************************************
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 106ms/step
# Image file: C02_WHI_357.png
# Predicted class: c02 - Trimeresurus albolabris
# ********************************************************************
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 101ms/step
# Image file: C02_WHI_358.png
# Predicted class: c02 - Trimeresurus albolabris
# ********************************************************************
# 1/1 [==============================] - 0s 114ms/step
# Image file: C02_WHI_359.png
# Predicted class: non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 102ms/step
# Image file: C02_WHI_360.png
# Predicted class: c02 - Trimeresurus albolabris
# ********************************************************************
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 103ms/step
# Image file: C03_STR_351.png
# Predicted class: c03 - Oligodon taeniatus
# ********************************************************************
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 128ms/step
# Image file: C03_STR_352.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 100ms/step
# Image file: C03_STR_353.png
# Predicted class: c03 - Oligodon taeniatus
# ********************************************************************
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 101ms/step
# Image file: C03_STR_354.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 100ms/step
# Image file: C03_STR_355.png
# Predicted class: c03 - Oligodon taeniatus
# ********************************************************************
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 100ms/step
# Image file: C03_STR_356.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 104ms/step
# Image file: C03_STR_357.png
# Predicted class: c03 - Oligodon taeniatus
# ********************************************************************
# 1/1 [==============================] - 0s 116ms/step
# Image file: C03_STR_358.png
# Predicted class: non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 100ms/step
# Image file: C03_STR_359.png
# Predicted class: c03 - Oligodon taeniatus
# ********************************************************************
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 135ms/step
# Image file: C03_STR_360.png
# Predicted class: c06 - Ptyas mucosa
# ********************************************************************
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 108ms/step
# Image file: C04_COP_351.png
# Predicted class: c06 - Ptyas mucosa
# ********************************************************************
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 104ms/step
# Image file: C04_COP_352.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 99ms/step
# Image file: C04_COP_353.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 102ms/step
# Image file: C04_COP_354.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 104ms/step
# Image file: C04_COP_355.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 97ms/step
# Image file: C04_COP_356.png
# Predicted class: c06 - Ptyas mucosa
# ********************************************************************
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 113ms/step
# Image file: C04_COP_357.png
# Predicted class: c04 - Coelognathus radiatus
# ********************************************************************
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 100ms/step
# Image file: C04_COP_358.png
# Predicted class: c03 - Oligodon taeniatus
# ********************************************************************
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 103ms/step
# Image file: C04_COP_359.png
# Predicted class: c03 - Oligodon taeniatus
# ********************************************************************
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 100ms/step
# Image file: C04_COP_360.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 102ms/step
# Image file: C05_BAN_351.jpg
# Predicted class: c05 - Oligodon fasciolatus
# ********************************************************************
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 100ms/step
# Image file: C05_BAN_352.jpg
# Predicted class: c06 - Ptyas mucosa
# ********************************************************************
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 100ms/step
# Image file: C05_BAN_353.jpg
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 101ms/step
# Image file: C05_BAN_354.jpg
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 97ms/step
# Image file: C05_BAN_355.jpg
# Predicted class: c06 - Ptyas mucosa
# ********************************************************************
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 103ms/step
# Image file: C05_BAN_356.jpg
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 96ms/step
# Image file: C05_BAN_357.jpg
# Predicted class: c05 - Oligodon fasciolatus
# ********************************************************************
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 99ms/step
# Image file: C05_BAN_358.jpg
# Predicted class: c06 - Ptyas mucosa
# ********************************************************************
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 105ms/step
# Image file: C05_BAN_359.jpg
# Predicted class: c05 - Oligodon fasciolatus
# ********************************************************************
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 95ms/step
# Image file: C05_BAN_360.jpg
# Predicted class: c05 - Oligodon fasciolatus
# ********************************************************************
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 98ms/step
# Image file: C06_ORI_351.jpg
# Predicted class: c01 - Chrysopelea ornata
# ********************************************************************
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 100ms/step
# Image file: C06_ORI_352.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 105ms/step
# Image file: C06_ORI_353.png
# Predicted class: c08 - Malayopython reticulatus
# ********************************************************************
# 1/1 [==============================] - 0s 105ms/step
# Image file: C06_ORI_354.png
# Predicted class: non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 100ms/step
# Image file: C06_ORI_355.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 99ms/step
# Image file: C06_ORI_356.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 105ms/step
# Image file: C06_ORI_357.jpg
# Predicted class: non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 109ms/step
# Image file: C06_ORI_358.jpg
# Predicted class: non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 103ms/step
# Image file: C06_ORI_359.jpg
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 102ms/step
# Image file: C06_ORI_360.jpg
# Predicted class: c06 - Ptyas mucosa
# ********************************************************************
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 104ms/step
# Image file: C07_SUN_351.jpeg
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 103ms/step
# Image file: C07_SUN_352.jpeg
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 98ms/step
# Image file: C07_SUN_353.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 104ms/step
# Image file: C07_SUN_354.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 99ms/step
# Image file: C07_SUN_355.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 114ms/step
# Image file: C07_SUN_356.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 105ms/step
# Image file: C07_SUN_357.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 99ms/step
# Image file: C07_SUN_358.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 101ms/step
# Image file: C07_SUN_359.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 103ms/step
# Image file: C07_SUN_360.jpeg
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 111ms/step
# Image file: C08_RET_351.png
# Predicted class: non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 101ms/step
# Image file: C08_RET_352.png
# Predicted class: non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 104ms/step
# Image file: C08_RET_353.png
# Predicted class: c08 - Malayopython reticulatus
# ********************************************************************
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 104ms/step
# Image file: C08_RET_354.png
# Predicted class: c08 - Malayopython reticulatus
# ********************************************************************
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 102ms/step
# Image file: C08_RET_355.png
# Predicted class: c08 - Malayopython reticulatus
# ********************************************************************
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 102ms/step
# Image file: C08_RET_356.png
# Predicted class: c08 - Malayopython reticulatus
# ********************************************************************
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 101ms/step
# Image file: C08_RET_357.png
# Predicted class: c08 - Malayopython reticulatus
# ********************************************************************
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 104ms/step
# Image file: C08_RET_358.png
# Predicted class: c08 - Malayopython reticulatus
# ********************************************************************
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 93ms/step
# Image file: C08_RET_359.png
# Predicted class: c08 - Malayopython reticulatus
# ********************************************************************
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 112ms/step
# Image file: C08_RET_360.png
# Predicted class: c08 - Malayopython reticulatus
# ********************************************************************
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 100ms/step
# Image file: C09_MON_351.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 103ms/step
# Image file: C09_MON_352.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 137ms/step
# Image file: C09_MON_353.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 111ms/step
# Image file: C09_MON_354.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 106ms/step
# Image file: C09_MON_355.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 131ms/step
# Image file: C09_MON_356.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 99ms/step
# Image file: C09_MON_357.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 128ms/step
# Image file: C09_MON_358.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 99ms/step
# Image file: C09_MON_359.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 103ms/step
# Image file: C09_MON_360.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 105ms/step
# Image file: C10_NON_351.png
# Predicted class: non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 99ms/step
# Image file: C10_NON_352.png
# Predicted class: c03 - Oligodon taeniatus
# ********************************************************************
# 1/1 [==============================] - 0s 114ms/step
# Image file: C10_NON_353.png
# Predicted class: non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 106ms/step
# Image file: C10_NON_354.png
# Predicted class: non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 105ms/step
# Image file: C10_NON_355.png
# Predicted class: non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 108ms/step
# Image file: C10_NON_356.png
# Predicted class: non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 106ms/step
# Image file: C10_NON_357.png
# Predicted class: non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 122ms/step
# Image file: C10_NON_358.png
# Predicted class: non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 128ms/step
# Image file: C10_NON_359.png
# Predicted class: non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 130ms/step
# Image file: C10_NON_360.png
# Predicted class: c02 - Trimeresurus albolabris
# ********************************************************************

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(reality, predictions)
print('Accuracy: %f' % accuracy)

# precision tp / (tp + fp)
precision = precision_score(reality, predictions, average='weighted')
print('Precision: %f' % precision)

# recall: tp / (tp + fn)
recall = recall_score(reality, predictions, average='weighted')
print('Recall: %f' % recall)

# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(reality, predictions, average='weighted')
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.620000
# Precision: 0.697518
# Recall: 0.620000
# F1 score: 0.592556

# %%
import seaborn as sn
import pandas as pd
from sklearn.metrics import confusion_matrix, multilabel_confusion_matrix

class_names = ('c01', 'c02', 'c03', 'c04', 'c05', 'c06', 'c07', 'c08', 'c09', 'c10')

confusion_mtx = confusion_matrix(reality, predictions)

dataframe = pd.DataFrame(confusion_mtx, index=class_names, columns=class_names)

ax = plt.axes()
sn.heatmap(dataframe, annot=True,annot_kws={"size": 12}, cmap="inferno_r", ax = ax, fmt=".0f")
ax.set_title('Accuracy', size=14)
plt.xlabel('Predictions', fontsize=11)
plt.ylabel('Actuals', fontsize=11)
plt.savefig('./saved_result/FINAL/Resnet50-M1-heatmap.png')
plt.show()

# %% [markdown]
# ### M2 - Resnet50 (RAW)

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import load_model

# Load the trained model
multiclass_model = load_model('./model/Resnet50_M2_model.h5')

#define the path of testing set
Test_path = './unknown_eval/'

#create reality list
reality = []
for value in os.listdir(Test_path):
    for img in os.listdir(Test_path + value):
        
        if value.lower() == "c01":
            reality.append(0)

        elif value.lower() == "c02":
            reality.append(1)

        elif value.lower() == "c03":
            reality.append(2)

        elif value.lower() == "c04":
            reality.append(3)

        elif value.lower() == "c05":
            reality.append(4)

        elif value.lower() == "c06":
            reality.append(5)

        elif value.lower() == "c07":
            reality.append(6)

        elif value.lower() == "c08":
            reality.append(7)
            
        elif value.lower() == "c09":
            reality.append(8)

        else: 
            reality.append(9)


# Define the dictionary mapping the species class indices to the class names
species_names = {0: 'c01 - Chrysopelea ornata',
               1: 'c02 - Trimeresurus albolabris',
               2: 'c03 - Oligodon taeniatus',
               3: 'c04 - Coelognathus radiatus',
               4: 'c05 - Oligodon fasciolatus',
               5: 'c06 - Ptyas mucosa',
               6: 'c07 - Xenopeltis unicolor',
               7: 'c08 - Malayopython reticulatus',
               8: 'c09 - Naja kaouthia',
               9: 'c10 - Non-snake'}

# Set the directory of the images to be tested
test_dir = './unknown/'

#create prediction list
predictions = []

# Loop through each image file in the directory
for filename in os.listdir(test_dir):
    if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.jpeg'):
        # Load the image
        img_path = os.path.join(test_dir, filename)
        img = tf.keras.utils.load_img(img_path, color_mode='rgb', target_size=(224, 224))
        img_array = tf.keras.utils.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)

        # Apply the prediction model
        prediction = multiclass_model.predict(img_array)
        predicted_class = np.argmax(prediction)

        # Print the predicted class
        print('Image file:', filename)
        print('Predicted class:', species_names[predicted_class])
        print('********************************************************************')

        predictions.append(predicted_class)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Image file: C01_ORN_351.png
# Predicted class: c01 - Chrysopelea ornata
# ********************************************************************
# 1/1 [==============================] - 0s 127ms/step
# Image file: C01_ORN_352.png
# Predicted class: c01 - Chrysopelea ornata
# ********************************************************************
# 1/1 [==============================] - 0s 107ms/step
# Image file: C01_ORN_353.png
# Predicted class: c01 - Chrysopelea ornata
# ********************************************************************
# 1/1 [==============================] - 0s 138ms/step
# Image file: C01_ORN_354.png
# Predicted class: c03 - Oligodon taeniatus
# ********************************************************************
# 1/1 [==============================] - 0s 109ms/step
# Image file: C01_ORN_355.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 118ms/step
# Image file: C01_ORN_356.png
# Predicted class: c01 - Chrysopelea ornata
# ********************************************************************
# 1/1 [==============================] - 0s 116ms/step
# Image file: C01_ORN_357.png
# Predicted class: c01 - Chrysopelea ornata
# ********************************************************************
# 1/1 [==============================] - 0s 121ms/step
# Image file: C01_ORN_358.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 130ms/step
# Image file: C01_ORN_359.png
# Predicted class: c01 - Chrysopelea ornata
# ********************************************************************
# 1/1 [==============================] - 0s 115ms/step
# Image file: C01_ORN_360.png
# Predicted class: c02 - Trimeresurus albolabris
# ********************************************************************
# 1/1 [==============================] - 0s 111ms/step
# Image file: C02_WHI_351.jpg
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 109ms/step
# Image file: C02_WHI_352.jpg
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 116ms/step
# Image file: C02_WHI_353.jpg
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 133ms/step
# Image file: C02_WHI_354.png
# Predicted class: c02 - Trimeresurus albolabris
# ********************************************************************
# 1/1 [==============================] - 0s 110ms/step
# Image file: C02_WHI_355.png
# Predicted class: c02 - Trimeresurus albolabris
# ********************************************************************
# 1/1 [==============================] - 0s 108ms/step
# Image file: C02_WHI_356.png
# Predicted class: c02 - Trimeresurus albolabris
# ********************************************************************
# 1/1 [==============================] - 0s 103ms/step
# Image file: C02_WHI_357.png
# Predicted class: c02 - Trimeresurus albolabris
# ********************************************************************
# 1/1 [==============================] - 0s 104ms/step
# Image file: C02_WHI_358.png
# Predicted class: c02 - Trimeresurus albolabris
# ********************************************************************
# 1/1 [==============================] - 0s 101ms/step
# Image file: C02_WHI_359.png
# Predicted class: c02 - Trimeresurus albolabris
# ********************************************************************
# 1/1 [==============================] - 0s 108ms/step
# Image file: C02_WHI_360.png
# Predicted class: c02 - Trimeresurus albolabris
# ********************************************************************
# 1/1 [==============================] - 0s 119ms/step
# Image file: C03_STR_351.png
# Predicted class: c04 - Coelognathus radiatus
# ********************************************************************
# 1/1 [==============================] - 0s 129ms/step
# Image file: C03_STR_352.png
# Predicted class: c03 - Oligodon taeniatus
# ********************************************************************
# 1/1 [==============================] - 0s 108ms/step
# Image file: C03_STR_353.png
# Predicted class: c03 - Oligodon taeniatus
# ********************************************************************
# 1/1 [==============================] - 0s 111ms/step
# Image file: C03_STR_354.png
# Predicted class: c03 - Oligodon taeniatus
# ********************************************************************
# 1/1 [==============================] - 0s 107ms/step
# Image file: C03_STR_355.png
# Predicted class: c03 - Oligodon taeniatus
# ********************************************************************
# 1/1 [==============================] - 0s 107ms/step
# Image file: C03_STR_356.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 107ms/step
# Image file: C03_STR_357.png
# Predicted class: c03 - Oligodon taeniatus
# ********************************************************************
# 1/1 [==============================] - 0s 107ms/step
# Image file: C03_STR_358.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 115ms/step
# Image file: C03_STR_359.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 110ms/step
# Image file: C03_STR_360.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 103ms/step
# Image file: C04_COP_351.png
# Predicted class: c06 - Ptyas mucosa
# ********************************************************************
# 1/1 [==============================] - 0s 115ms/step
# Image file: C04_COP_352.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 127ms/step
# Image file: C04_COP_353.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 116ms/step
# Image file: C04_COP_354.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 108ms/step
# Image file: C04_COP_355.png
# Predicted class: c03 - Oligodon taeniatus
# ********************************************************************
# 1/1 [==============================] - 0s 112ms/step
# Image file: C04_COP_356.png
# Predicted class: c06 - Ptyas mucosa
# ********************************************************************
# 1/1 [==============================] - 0s 144ms/step
# Image file: C04_COP_357.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 110ms/step
# Image file: C04_COP_358.png
# Predicted class: c06 - Ptyas mucosa
# ********************************************************************
# 1/1 [==============================] - 0s 103ms/step
# Image file: C04_COP_359.png
# Predicted class: c02 - Trimeresurus albolabris
# ********************************************************************
# 1/1 [==============================] - 0s 106ms/step
# Image file: C04_COP_360.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 108ms/step
# Image file: C05_BAN_351.jpg
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 109ms/step
# Image file: C05_BAN_352.jpg
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 135ms/step
# Image file: C05_BAN_353.jpg
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 123ms/step
# Image file: C05_BAN_354.jpg
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 128ms/step
# Image file: C05_BAN_355.jpg
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 113ms/step
# Image file: C05_BAN_356.jpg
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 133ms/step
# Image file: C05_BAN_357.jpg
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 114ms/step
# Image file: C05_BAN_358.jpg
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 119ms/step
# Image file: C05_BAN_359.jpg
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 116ms/step
# Image file: C05_BAN_360.jpg
# Predicted class: c05 - Oligodon fasciolatus
# ********************************************************************
# 1/1 [==============================] - 0s 121ms/step
# Image file: C06_ORI_351.jpg
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 111ms/step
# Image file: C06_ORI_352.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 130ms/step
# Image file: C06_ORI_353.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 119ms/step
# Image file: C06_ORI_354.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 109ms/step
# Image file: C06_ORI_355.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 115ms/step
# Image file: C06_ORI_356.png
# Predicted class: c06 - Ptyas mucosa
# ********************************************************************
# 1/1 [==============================] - 0s 107ms/step
# Image file: C06_ORI_357.jpg
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 126ms/step
# Image file: C06_ORI_358.jpg
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 119ms/step
# Image file: C06_ORI_359.jpg
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 203ms/step
# Image file: C06_ORI_360.jpg
# Predicted class: c06 - Ptyas mucosa
# ********************************************************************
# 1/1 [==============================] - 0s 122ms/step
# Image file: C07_SUN_351.jpeg
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 132ms/step
# Image file: C07_SUN_352.jpeg
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 129ms/step
# Image file: C07_SUN_353.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 104ms/step
# Image file: C07_SUN_354.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 120ms/step
# Image file: C07_SUN_355.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 118ms/step
# Image file: C07_SUN_356.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 104ms/step
# Image file: C07_SUN_357.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 102ms/step
# Image file: C07_SUN_358.png
# Predicted class: c06 - Ptyas mucosa
# ********************************************************************
# 1/1 [==============================] - 0s 104ms/step
# Image file: C07_SUN_359.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 108ms/step
# Image file: C07_SUN_360.jpeg
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************
# 1/1 [==============================] - 0s 108ms/step
# Image file: C08_RET_351.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 129ms/step
# Image file: C08_RET_352.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 131ms/step
# Image file: C08_RET_353.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 126ms/step
# Image file: C08_RET_354.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 107ms/step
# Image file: C08_RET_355.png
# Predicted class: c08 - Malayopython reticulatus
# ********************************************************************
# 1/1 [==============================] - 0s 109ms/step
# Image file: C08_RET_356.png
# Predicted class: c06 - Ptyas mucosa
# ********************************************************************
# 1/1 [==============================] - 0s 114ms/step
# Image file: C08_RET_357.png
# Predicted class: c08 - Malayopython reticulatus
# ********************************************************************
# 1/1 [==============================] - 0s 104ms/step
# Image file: C08_RET_358.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 105ms/step
# Image file: C08_RET_359.png
# Predicted class: c08 - Malayopython reticulatus
# ********************************************************************
# 1/1 [==============================] - 0s 104ms/step
# Image file: C08_RET_360.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 108ms/step
# Image file: C09_MON_351.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 103ms/step
# Image file: C09_MON_352.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 106ms/step
# Image file: C09_MON_353.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 109ms/step
# Image file: C09_MON_354.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 106ms/step
# Image file: C09_MON_355.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 122ms/step
# Image file: C09_MON_356.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 121ms/step
# Image file: C09_MON_357.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 108ms/step
# Image file: C09_MON_358.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 108ms/step
# Image file: C09_MON_359.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 134ms/step
# Image file: C09_MON_360.png
# Predicted class: c09 - Naja kaouthia
# ********************************************************************
# 1/1 [==============================] - 0s 136ms/step
# Image file: C10_NON_351.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 108ms/step
# Image file: C10_NON_352.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 108ms/step
# Image file: C10_NON_353.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 126ms/step
# Image file: C10_NON_354.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 111ms/step
# Image file: C10_NON_355.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 118ms/step
# Image file: C10_NON_356.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 114ms/step
# Image file: C10_NON_357.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 118ms/step
# Image file: C10_NON_358.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 102ms/step
# Image file: C10_NON_359.png
# Predicted class: c10 - Non-snake
# ********************************************************************
# 1/1 [==============================] - 0s 105ms/step
# Image file: C10_NON_360.png
# Predicted class: c07 - Xenopeltis unicolor
# ********************************************************************

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(reality, predictions)
print('Accuracy: %f' % accuracy)

# precision tp / (tp + fp)
precision = precision_score(reality, predictions, average='weighted')
print('Precision: %f' % precision)

# recall: tp / (tp + fn)
recall = recall_score(reality, predictions, average='weighted')
print('Recall: %f' % recall)

# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(reality, predictions, average='weighted')
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.460000
# Precision: 0.624444
# Recall: 0.460000
# F1 score: 0.450100

# %%
import seaborn as sn
import pandas as pd
from sklearn.metrics import confusion_matrix, multilabel_confusion_matrix

class_names = ('c01', 'c02', 'c03', 'c04', 'c05', 'c06', 'c07', 'c08', 'c09', 'c10')

confusion_mtx = confusion_matrix(reality, predictions)

dataframe = pd.DataFrame(confusion_mtx, index=class_names, columns=class_names)

ax = plt.axes()
sn.heatmap(dataframe, annot=True,annot_kws={"size": 12}, cmap="inferno_r", ax = ax, fmt=".0f")
ax.set_title('Accuracy', size=14)
plt.xlabel('Predictions', fontsize=11)
plt.ylabel('Actuals', fontsize=11)
plt.savefig('./saved_result/FINAL/Resnet50-M2-heatmap.png')
plt.show()
